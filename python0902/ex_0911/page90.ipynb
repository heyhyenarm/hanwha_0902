# %%
from langchain_openai import ChatOpenAI

# %%
# 객체 생성
# llm = ChatOpenAI(                   
#     temperature=0.1,                # 창의성 (0.0 ~ 2.0)
#     model_name="gpt-5.6-luna",      # 모델명
# )
llm_with_logprob = ChatOpenAI(
    temperature=0.1,
    max_completion_tokens=2048,    # 최대 토큰 수 
    model="gpt-4o-mini",
    logprobs=True
)

# # 질의 내용
question = "대한민국의 수도는?"             
# # 질의
# # response = llm.invoke(question)
response = llm_with_logprob.invoke(question)

# stream() 함수로 출력하기. 스트리밍 출력.
# stream 방식으로 질의하고 답변 결과를 받음. 
# answer = llm.stream("천안 불당동 맛집 10곳 알려줘")

# %%
# print(response.content)
print(response.response_metadata)
# print(response.response_metadata["token_usage"])

print(llm_with_logprob.logprobs)

# streaming 방식으로 각 토큰 출력
# for token in answer:
#     print(token.content, end="", flush=True)

# final_answer = ""
# for token in answer:
#     final_answer += token.content

# print(final_answer)
# Out:
# {'token_usage': {'completion_tokens': 8, 'prompt_tokens': 13, 'total_tokens': 21, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b25ddc7e38', 'id': 'chatcmpl-EMqNLgex0Fao12c3jRN1vfp5197i1', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': {'content': [{'token': '대한', 'bytes': [235, 140, 128, 237, 149, 156], 'logprob': -1.4498052223643754e-05, 'top_logprobs': []}, {'token': '민국', 'bytes': [235, 175, 188, 234, 181, 173], 'logprob': -1.0280383548888494e-06, 'top_logprobs': []}, {'token': '의', 'bytes': [236, 157, 152], 'logprob': -2.8087270038668066e-05, 'top_logprobs': []}, {'token': ' 수도', 'bytes': [32, 236, 136, 152, 235, 143, 132], 'logprob': -9.329167369287461e-05, 'top_logprobs': []}, {'token': '는', 'bytes': [235, 138, 148], 'logprob': -4.978233846486546e-05, 'top_logprobs': []}, {'token': ' 서울', 'bytes': [32, 236, 132, 156, 236, 154, 184], 'logprob': -0.0001951961312443018, 'top_logprobs': []}, {'token': '입니다', 'bytes': [236, 158, 133, 235, 139, 136, 235, 139, 164], 'logprob': -0.004401274956762791, 'top_logprobs': []}, {'token': '.', 'bytes': [46], 'logprob': -1.9361264946837764e-07, 'top_logprobs': []}], 'refusal': None}}
# True
