# %%
#!ollama pull nomic-embed-text
#!pip install dotenv
#!pip install langchain-teddynote

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_teddynote import logging

logging.langsmith("CH11-Embeddings")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH11-Embeddings

# %%
texts = [
    "안녕, 만나서 반가워.",
    "LangChain simplifies the process of building applications with large language models",
    "랭체인 한국어 튜토리얼은 LangChain의 공식 문서, cookbook 및 다양한 실용 예제를 바탕으로 하여 사용자가 LangChain을 더 쉽고 효과적으로 활용할 수 있도록 구성되어 있습니다. ",
    "LangChain은 초거대 언어모델로 애플리케이션을 구축하는 과정을 단순화합니다.",
    "Retrieval-Augmented Generation (RAG) is an effective technique for improving AI responses.",
]

# %%
#!pip install langchain_community
from langchain_community.embeddings import OllamaEmbeddings

ollama_embeddings = OllamaEmbeddings(
    model = "nomic-embed-text",
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20516\3163602358.py:4: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   ollama_embeddings = OllamaEmbeddings(

# %%
embedded_query = ollama_embeddings.embed_query("Langchain에 대해서 상세히 알려주세요.")
len(embedded_query)
# Out:
# 768

# %%
embedded_documents = ollama_embeddings.embed_documents(texts)

# %%
import numpy as np

similarity = np.array(embedded_query) @ np.array(embedded_documents).T
sorted_idx = (np.array(embedded_query) @ np.array(embedded_documents).T).argsort()[::-1]

print("[Query] LangChain에 대해서 알려주세요. \n==========================================")
for i, idx in enumerate(sorted_idx):
    print(f"[{i}] 유사도: {similarity[idx]: .3f} | {texts[idx]}")
# Out:
# [Query] LangChain에 대해서 알려주세요.
# ==========================================
# [0] 유사도:  402.205 | LangChain은 초거대 언어모델로 애플리케이션을 구축하는 과정을 단순화합니다.
# [1] 유사도:  356.527 | 랭체인 한국어 튜토리얼은 LangChain의 공식 문서, cookbook 및 다양한 실용 예제를 바탕으로 하여 사용자가 LangChain을 더 쉽고 효과적으로 활용할 수 있도록 구성되어 있습니다.
# [2] 유사도:  325.376 | LangChain simplifies the process of building applications with large language models
# [3] 유사도:  314.810 | 안녕, 만나서 반가워.
# [4] 유사도:  223.638 | Retrieval-Augmented Generation (RAG) is an effective technique for improving AI responses.
