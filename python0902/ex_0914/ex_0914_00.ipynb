# %%
# 오른쪽 위 Select Kernal에서 가상환경으로 커널 잡아주기. 
# 가상환경 위치 확인
#!pip --version
# Out:
# pip 25.0.1 from D:\hanwha_0902\python0902\ex_0914\.venv\Lib\site-packages\pip (python 3.12)

# %%
#!pip install dotenv

# %%
from dotenv import load_dotenv

# .env 파일에 설정된 보안정보를 읽기.
load_dotenv()
# Out:
# True

# %%
import os

# 설정된 키 값을 확인: 키 값이 노출되지 않도록 확인 후 8글자만 출력하도록 변경함.
print(f"키 값은: {os.environ['OPENAI_API_KEY'][:8]}")
# Out:
# 키 값은: sk-proj-
